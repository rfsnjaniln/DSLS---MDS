# %% [markdown]
# ## Import Library

# %%
import numpy as np
import pandas as pd
import warnings
import seaborn as sns
import matplotlib.pyplot as plt
import datetime
warnings.filterwarnings('ignore')
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
# pd.set_option("max_colwidth", None)

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Read Data

# %%
# df = pd.read_csv("https://docs.google.com/spreadsheets/d/1DH8QwC_i4TSFfTIJu2uSjmh_a6pvWn8_gAwa1agnxxw/edit?usp=drive_web&ouid=109065574320047379709")
# display(f'total data keseluruhan sebanyak', len(df))
# display(df.sample(5))

# %%
df2 = pd.read_csv("/content/drive/My Drive/DATA CONSULTANT 2023/MINI PROJECT DS/Rafsan/aggregate_median_irregularities_Kota Bandung.csv", sep=',', header=0)
display(f'total data keseluruhan sebanyak', len(df2))
display(df2.sample(5))
# Out:
# 'total data keseluruhan sebanyak'
# 11281
#                           time  kemendagri_kabupaten_kode  \
# 422    2022-07-07 19:00:00.000                      32.73
# 10140  2022-08-30 15:00:00.000                      32.73
# 318    2022-07-07 14:00:00.000                      32.73
# 6902   2022-08-12 17:00:00.000                      32.73
# 9517   2022-08-27 12:00:00.000                      32.73
#
#       kemendagri_kabupaten_nama              street  jam_level  median_length  \
# 422                KOTA BANDUNG   Terusan Buah Batu          3         1572.0
# 10140              KOTA BANDUNG  N11 Soekarno-Hatta          4          672.0
# 318                KOTA BANDUNG         Ciumbuleuit          4          879.0
# 6902               KOTA BANDUNG        Dr Setiabudi          3         1418.0
# 9517               KOTA BANDUNG  N11 Soekarno-Hatta          4         1668.0
#
#        median_delay_seconds  median_regular_speed  total_records  cause_type  \
# ...

# %%
# df.info()

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11281 entries, 0 to 11280
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   time                       11281 non-null  object
#  1   kemendagri_kabupaten_kode  11281 non-null  float64
#  2   kemendagri_kabupaten_nama  11281 non-null  object
#  3   street                     11279 non-null  object
#  4   jam_level                  11281 non-null  int64
#  5   median_length              11281 non-null  float64
#  6   median_delay_seconds       11281 non-null  float64
#  7   median_regular_speed       11281 non-null  float64
#  8   total_records              11281 non-null  int64
#  9   cause_type                 0 non-null      float64
#  10  median_seconds             11281 non-null  float64
#  11  median_speed               11281 non-null  float64
#  12  date                       11281 non-null  object
# ...

# %%
for i in df2.columns:
    print(f"{[i]} \n {df2[i].unique()} \n")
# Out:
# ['time']
#  ['2022-07-06 07:00:00.000' '2022-07-06 08:00:00.000'
#  '2022-07-06 09:00:00.000' '2022-07-06 10:00:00.000'
#  '2022-07-06 11:00:00.000' '2022-07-06 12:00:00.000'
#  '2022-07-06 13:00:00.000' '2022-07-06 14:00:00.000'
#  '2022-07-06 15:00:00.000' '2022-07-06 16:00:00.000'
#  '2022-07-06 17:00:00.000' '2022-07-06 18:00:00.000'
#  '2022-07-06 19:00:00.000' '2022-07-06 20:00:00.000'
#  '2022-07-06 22:00:00.000' '2022-07-07 08:00:00.000'
#  '2022-07-07 09:00:00.000' '2022-07-07 10:00:00.000'
#  '2022-07-07 11:00:00.000' '2022-07-07 12:00:00.000'
#  '2022-07-07 13:00:00.000' '2022-07-07 14:00:00.000'
#  '2022-07-07 15:00:00.000' '2022-07-07 16:00:00.000'
#  '2022-07-07 17:00:00.000' '2022-07-07 18:00:00.000'
#  '2022-07-07 19:00:00.000' '2022-07-07 20:00:00.000'
#  '2022-07-07 21:00:00.000' '2022-07-08 07:00:00.000'
#  '2022-07-08 08:00:00.000' '2022-07-08 09:00:00.000'
#  '2022-07-08 10:00:00.000' '2022-07-08 11:00:00.000'
# ...

# %% [markdown]
# Karena feature 'kemendagri_kabupaten_kode' dan 'kemendagri_kabupaten_nama' hanya memiliki 1 jenis value sehingga akan di drop dikarenakan tidak memberikan informasi yang begitu bermakna untuk dimodelingkan

# %%
plt.figure(figsize = (15,15))
plt.pie(df2["jam_level"].value_counts(), labels=df2["jam_level"].value_counts().index, autopct='%1.2f%%', labeldistance = 1.1)
plt.title("jam_level")
plt.show()

# %%
df2 = df2.drop(['kemendagri_kabupaten_kode' , 'kemendagri_kabupaten_nama'], axis=1)
df2.head(2)
# Out:
#                       time                street  jam_level  median_length  \
# 0  2022-07-06 07:00:00.000     Terusan Buah Batu          4         1922.0
# 1  2022-07-06 07:00:00.000  Jenderal AH Nasution          3         1819.0
#
#    median_delay_seconds  median_regular_speed  total_records  cause_type  \
# 0                 657.0             15.770000             13         NaN
# 1                 421.0             17.939999              2         NaN
#
#    median_seconds  median_speed        date  median_jam_level       id  \
# 0           844.0          7.51  2022-07-06               4.0  1492848
# 1           572.0         11.60  2022-07-06               3.0  1492844
#
#                                             geometry
# 0  MULTILINESTRING ((107.638019 -6.965016, 107.63...
# 1  LINESTRING (107.678021 -6.904799, 107.677631 -...

# %%
from datetime import datetime

# %%
# mem-parsing kolom 'date_time' menjadi objek Datetime
df2['date_time'] = pd.to_datetime(df2['time'], format='%Y-%m-%d %H:%M:%S')
df2['time'] = pd.to_datetime(df2['date_time']).apply(lambda x: datetime.strftime(x, '%H'))

# membuat kolom baru untuk tanggal
df2['date'] = df2['date_time'].dt.date

# %%
df2['date'] = df2['date'].astype(str)
df2[['year', 'month', 'day']] = df2['date'].str.split('-', expand=True)
df2['year'] = df2['year'].astype(int)
df2['month'] = df2['month'].astype(int)
df2['day'] = df2['day'].astype(int)
df2.head(3)
# Out:
#   time                street  jam_level  median_length  median_delay_seconds  \
# 0   07     Terusan Buah Batu          4         1922.0                 657.0
# 1   07  Jenderal AH Nasution          3         1819.0                 421.0
# 2   07  Jenderal AH Nasution          4         1064.0                 586.0
#
#    median_regular_speed  total_records  cause_type  median_seconds  \
# 0             15.770000             13         NaN           844.0
# 1             17.939999              2         NaN           572.0
# 2             14.520000             11         NaN           675.0
#
#    median_speed        date  median_jam_level       id  \
# 0          7.51  2022-07-06               4.0  1492848
# 1         11.60  2022-07-06               3.0  1492844
# 2          6.14  2022-07-06               4.0  1492845
#
#                                             geometry           date_time  \
# 0  MULTILINESTRING ((107.638019 -6.965016, 107.63... 2022-07-06 07:00:00
# ...

# %%
df2 = df2.drop('median_jam_level', axis=1)

# %%
EDUCATION1 = df2.groupby(['street', 'jam_level']).agg(NumUsers=('id','count')).reset_index()
EDUCATION2 = df2.groupby('street')['id'].count().reset_index()
df_EDUCATION = EDUCATION1.merge(EDUCATION2, on='street')
df_EDUCATION['ratio'] = round(df_EDUCATION['NumUsers']/df_EDUCATION['id']*100,2)
df_EDUCATION
# Out:
#                                  street  jam_level  NumUsers   id   ratio
# 0                    Abdul Rahman Saleh          3        33  102   32.35
# 1                    Abdul Rahman Saleh          4        69  102   67.65
# 2                       Ajudan Jenderal          3         3    5   60.00
# 3                       Ajudan Jenderal          4         2    5   40.00
# 4                               Anggrek          3         2    8   25.00
# 5                               Anggrek          4         6    8   75.00
# 6                              Antapani          4         1    1  100.00
# 7      Arah Marga Asih/Katapang/Soreang          4         2    2  100.00
# 8                       Arcamanik Endah          2         2   67    2.99
# 9                       Arcamanik Endah          3        27   67   40.30
# 10                      Arcamanik Endah          4        38   67   56.72
# 11                          Asia Afrika          2         1   23    4.35
# ...

# %%
df2 = df2.drop(['date_time','id','date','year'], axis=1)

# %% [markdown]
# ## Exploratory Data Analysis

# %%
list_item = []
for col in df2.columns:
    list_item.append([col, df2[col].dtype, df2[col].isna().sum(), 100*df2[col].isna().sum()/len(df2[col]), df2[col].nunique(), df2[col].unique()[:4]])
desc_df = pd.DataFrame(data=list_item, columns='feature data_type null_num null_pct unique_num unique_sample'.split())
desc_df.sort_values('null_pct', ascending=False)
# Out:
#                  feature data_type  null_num    null_pct  unique_num  \
# 7             cause_type   float64     11281  100.000000           0
# 1                 street    object         2    0.017729         229
# 0                   time    object         0    0.000000          24
# 2              jam_level     int64         0    0.000000           4
# 3          median_length   float64         0    0.000000        2480
# 4   median_delay_seconds   float64         0    0.000000        2128
# 5   median_regular_speed   float64         0    0.000000        4213
# 6          total_records     int64         0    0.000000         115
# 8         median_seconds   float64         0    0.000000        2318
# 9           median_speed   float64         0    0.000000        2914
# 10              geometry    object         0    0.000000       10605
# 11                 month     int64         0    0.000000           3
# 12                   day     int64         0    0.000000          31
#
# ...

# %% [markdown]
# karena setelah dicek, feature cause type 100% nilainya null sehingga langsung saja kita drop sedangkan street memiliki 2 values yang null (0,02 %) sehingga kita akan handle dengan modus sebelum EDA

# %%
df2 = df2.drop(['cause_type'], axis=1)
df2.isna().sum()
# Out:
# time                    0
# street                  2
# jam_level               0
# median_length           0
# median_delay_seconds    0
# median_regular_speed    0
# total_records           0
# median_seconds          0
# median_speed            0
# geometry                0
# month                   0
# day                     0
# dtype: int64

# %%
df2[df2.isnull().any(axis=1)]
# Out:
#       time street  jam_level  median_length  median_delay_seconds  \
# 11175   15    NaN          3          753.0                 272.5
# 11200   15    NaN          4          753.0                 441.0
#
#        median_regular_speed  total_records  median_seconds  median_speed  \
# 11175                  34.0             18           356.0          7.60
# 11200                  34.0              2           525.0          5.15
#
#                                                 geometry  month  day
# 11175  MULTILINESTRING ((107.705748 -6.946806, 107.70...      9    4
# 11200  LINESTRING (107.705748 -6.946806, 107.709939 -...      9    4

# %%
df2[df2['median_length'] == 753.0]
# Out:
#       time              street  jam_level  median_length  \
# 907     17  N11 Soekarno-Hatta          4          753.0
# 2478    09  N11 Soekarno-Hatta          4          753.0
# 2653    10  N11 Soekarno-Hatta          4          753.0
# 2927    08  N11 Soekarno-Hatta          4          753.0
# 3065    19  N11 Soekarno-Hatta          4          753.0
# 3183    14  N11 Soekarno-Hatta          4          753.0
# 3207    14  N11 Soekarno-Hatta          3          753.0
# 4007    16  N11 Soekarno-Hatta          4          753.0
# 4817    06  N11 Soekarno-Hatta          4          753.0
# 5033    07  N11 Soekarno-Hatta          4          753.0
# 6108    10  N11 Soekarno-Hatta          4          753.0
# 6629    15  N11 Soekarno-Hatta          4          753.0
# 9109    16  N11 Soekarno-Hatta          4          753.0
# 11175   15                 NaN          3          753.0
# 11200   15                 NaN          4          753.0
#
# ...

# %%
df2.loc[df2['street'].isnull(), 'street'] = 'N11 Soekarno-Hatta'
df2.isna().sum()
# Out:
# time                    0
# street                  0
# jam_level               0
# median_length           0
# median_delay_seconds    0
# median_regular_speed    0
# total_records           0
# median_seconds          0
# median_speed            0
# geometry                0
# month                   0
# day                     0
# dtype: int64

# %% [markdown]
# ### Descriptive Statistics

# %%
df2.describe().T
# Out:
#                         count         mean         std     min      25%  \
# jam_level             11281.0     3.547115    0.578823    1.00    3.000
# median_length         11281.0  1389.094983  853.658805  500.00  788.000
# median_delay_seconds  11281.0   584.486836  275.743863  -97.00  402.000
# median_regular_speed  11281.0    17.479740    9.133036    2.45   12.445
# total_records         11281.0    14.008067   14.956688    1.00    4.000
# median_seconds        11281.0   723.977174  308.161511  132.00  523.000
# median_speed          11281.0     7.430116    4.280327    0.88    4.670
# month                 11281.0     7.654463    0.622929    7.00    7.000
# day                   11281.0    15.862158    8.855252    1.00    8.000
#
#                            50%      75%       max
# jam_level                4.000     4.00      4.00
# median_length         1158.000  1742.00  13201.00
# median_delay_seconds   560.000   724.00   4368.50
# ...

# %%
df2.describe(exclude=[np.number]).T
# Out:
#           count unique                                                top  \
# time      11281     24                                                 17
# street    11281    229                                 N11 Soekarno-Hatta
# geometry  11281  10605  LINESTRING (107.58148 -6.882219, 107.581484 -6...
#
#           freq
# time      1605
# street     813
# geometry     9

# %%
# Grouping Features Based on Their Data Type

num = df2.select_dtypes(include=[np.number], exclude=[np.bool]).columns
cat = df2.select_dtypes(exclude=[np.number]).columns

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# ##### Numerical Features Analysis

# %%
# Create Boxplot for Each Numerical Feature

fig, axes = plt.subplots(2, 5, figsize=(17,9))
xy = [(0,0), (0,1), (0,2), (0,3), (0,4), 
      (1,0), (1,1), (1,2), (1,3), (1,4)]

for i in range(len(num)):
  sns.boxplot(y=df2[num[i]], ax=axes[xy[i]])
  plt.tight_layout()

# %%
# Create Distplot for Each Numerical Feature

plt.figure(figsize=(17,9))
for i in range(0, len(num)):
    plt.subplot(3, 5, i+1)
    sns.kdeplot(x=df2[num[i]], linewidth=1.5, shade=True)
    plt.xlabel(num[i])
    plt.tight_layout()

# %%
# Create Violinplot for Each Numerical Feature

plt.figure(figsize=(17,9))
for i in range(0, len(num)):
    plt.subplot(3, 5, i+1)
    sns.violinplot(y=df2[num[i]], linewidth=1.5)
    plt.xlabel(num[i])
    plt.tight_layout()

# %% [markdown]
# ##### Categorical Features Analysis

# %%
# fig, axes = plt.subplots(3, 3, figsize=(20,12))
# xy = [(0,0), (0,1), (0,2), (1,0), (1,1), (1,2), (2,0), (2,1)]

# for i in range(len(cat)):
#   if i == 0:
#     sns.countplot(y=df2[cat[i]], palette='viridis',ax=axes[xy[i]])
#   else:
#     sns.countplot(y=df2[cat[i]], palette='viridis', order= df2[cat[i]].value_counts().index, ax=axes[xy[i]])
# axes[2, 2].axis('off')
# axes[2, 0].set_yticklabels(['Weekday', 'Weekend'])
# axes[2, 1].set_yticklabels(['4','3','2','1'])
# plt.tight_layout()

# %% [markdown]
# ### Bivariate Analysis

# %% [markdown]
# #### Numerical Features Analysis

# %%
# Create Distplot per Purchase for Each Numerical Feature

plt.figure(figsize=(17,9))
for i in range(0, len(num)):
    plt.subplot(4, 5, i+1)
    sns.kdeplot(x=df2[num[i]], hue=df2['jam_level'],palette='viridis', linewidth=1.5)
    plt.xlabel(num[i])
    plt.tight_layout()

# %% [markdown]
# #### Categorical Features Analysis

# %%
# # Create Countplot per Purchase for Each Categorical Feature

# fig, axes = plt.subplots(3, 3, figsize=(20,12))
# xy = [(0,0), (0,1), (0,2), (1,0), (1,1), (1,2), (2,0), (2,1)]

# for i in range(len(cat)-1):
#   if i == 0:
#     sns.countplot(y=df2[cat[i]], hue=df2.jam_level, palette='viridis', ax=axes[xy[i]])
#     plt.tight_layout()
#   else:
#     sns.countplot(y=df2[cat[i]], hue=df2.jam_level, palette='viridis', order= df2[cat[i]].value_counts().index, ax=axes[xy[i]])
#     plt.tight_layout()
# axes[2, 1].axis('off')
# axes[2, 2].axis('off')
# axes[2, 0].axis('off')
# plt.tight_layout()

# %% [markdown]
# ### MultiVariate Analysis

# %%
# Create Heatmap Correlation Chart for Each Numerical Features

plt.figure(figsize=(12, 12))
sns.heatmap(df2.corr(), cmap='Blues', annot=True, fmt='.2f')

# %%
# Create Heatmap Correlation Chart for Each Numerical to Target Features

plt.figure(figsize=(6, 6))
sns.heatmap(df2.corr(method = 'kendall')[df2.corr(method = 'kendall').index != 'jam_level'][['jam_level']], cmap='Blues', annot=True, fmt='.2f')

# %%
# create pairplot
plt.figure(figsize=(15, 15))
sns.pairplot(df2[num], diag_kind='kde')

# %% [markdown]
# ## Pre-Processing

# %% [markdown]
# ### Handling Duplicated

# %%
# Check Duplicated Data

print(f'Number of duplicated data = {df2.duplicated().sum()}')
# Out:
# Number of duplicated data = 0

# %%
df2[cat].head()
# Out:
#   time                street  \
# 0   07     Terusan Buah Batu
# 1   07  Jenderal AH Nasution
# 2   07  Jenderal AH Nasution
# 3   07    N11 Soekarno-Hatta
# 4   07     Terusan Buah Batu
#
#                                             geometry
# 0  MULTILINESTRING ((107.638019 -6.965016, 107.63...
# 1  LINESTRING (107.678021 -6.904799, 107.677631 -...
# 2  MULTILINESTRING ((107.659819 -6.902242, 107.66...
# 3  MULTILINESTRING ((107.641468 -6.945648, 107.64...
# 4  LINESTRING (107.638019 -6.965016, 107.638179 -...

# %% [markdown]
# ### Categorical Features Encoding

# %%
# df_cat = pd.get_dummies(df2[cat].iloc[:,0:4])
# df_cat.head()

# %%
df2['jam_level'].value_counts()
# Out:
# 4    6635
# 3    4212
# 2     405
# 1      29
# Name: jam_level, dtype: int64

# %%
df2.head(5)
# Out:
#   time                street  jam_level  median_length  median_delay_seconds  \
# 0   07     Terusan Buah Batu          4         1922.0                 657.0
# 1   07  Jenderal AH Nasution          3         1819.0                 421.0
# 2   07  Jenderal AH Nasution          4         1064.0                 586.0
# 3   07    N11 Soekarno-Hatta          4          919.0                 558.5
# 4   07     Terusan Buah Batu          3         2024.0                 599.0
#
#    median_regular_speed  total_records  median_seconds  median_speed  \
# 0             15.770000             13           844.0          7.51
# 1             17.939999              2           572.0         11.60
# 2             14.520000             11           675.0          6.14
# 3             15.095000             20           632.0          4.97
# 4             15.830000              1           786.0          9.26
#
#                                             geometry  month  day
# ...

# %%
df2['street'].value_counts()
# Out:
# N11 Soekarno-Hatta                    813
# Jenderal AH Nasution                  555
# Terusan Buah Batu                     430
# Ir Haji Juanda                        379
# Prof Dr Surya Sumantri                346
# Margacinta                            316
# Jenderal Ibrahim Adjie                285
# Soekarno-Hatta (Jalur Lambat)         276
# Buah Batu                             276
# Holis                                 259
# Dr Djundjunan                         256
# Jenderal Ahmad Yani                   255
# Dr Setiabudi                          244
# LLRE Martadinata                      200
# Surapati                              194
# PHH Mustofa                           185
# Tubagus Ismail                        185
# WR Supratman                          155
# Jalan Rumah Sakit                     155
# Ciumbuleuit                           149
# Prof Mochtar Kusumaatmadja            147
# Cibaduyut Raya                        141
# ...

# %%
# df2['geometry'].value_counts()

# %% [markdown]
# ### Handle Outliers

# %%
fig, axes = plt.subplots(2, 5, figsize=(17,9))
xy = [(0,0), (0,1), (0,2), (0,3), (0,4), 
      (1,0), (1,1), (1,2), (1,3), (1,4)]

for i in range(len(num)):
  sns.boxplot(y=df2[num[i]], ax=axes[xy[i]])
  plt.tight_layout()

# %%
outlier_col = ['median_length', 'median_delay_seconds',
       'median_regular_speed', 'total_records', 'median_seconds',
       'median_speed']

# %%
from scipy import stats
import numpy as np

# Handling Outlier using Z-score

print(f'Total Rows Before Outlier Handling = {len(df2)}')

filtered_entries = np.array([True] * len(df2))

for col in outlier_col:
    zscore = abs(stats.zscore(df2[col]))
    filtered_entries = (zscore < 3) & filtered_entries 
    
data_final = df2[filtered_entries] 

print(f'Total Rows Before Outlier Handling = {len(data_final)}')
# Out:
# Total Rows Before Outlier Handling = 11281
# Total Rows Before Outlier Handling = 10612

# %% [markdown]
# ### Label Encode

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
data_final['street'] = le.fit_transform(data_final['street'])
data_final['geometry'] = le.fit_transform(data_final['geometry'])
data_final.reset_index(drop=True).head(5)
# Out:
#   time  street  jam_level  median_length  median_delay_seconds  \
# 0   07     211          4         1922.0                 657.0
# 1   07     120          3         1819.0                 421.0
# 2   07     120          4         1064.0                 586.0
# 3   07     155          4          919.0                 558.5
# 4   07     211          3         2024.0                 599.0
#
#    median_regular_speed  total_records  median_seconds  median_speed  \
# 0             15.770000             13           844.0          7.51
# 1             17.939999              2           572.0         11.60
# 2             14.520000             11           675.0          6.14
# 3             15.095000             20           632.0          4.97
# 4             15.830000              1           786.0          9.26
#
#    geometry  month  day
# 0      7621      7    6
# 1      1440      7    6
# 2      8934      7    6
# 3      7881      7    6
# 4      1089      7    6

# %% [markdown]
# ### Numerical Feature Scaling

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler, MinMaxScaler, StandardScaler

# %%
data_final['jam_level'].value_counts()
# Out:
# 4    6268
# 3    4056
# 2     284
# 1       4
# Name: jam_level, dtype: int64

# %%
# Splitting Data Train - Test
X_train, X_test, y_train, y_test = train_test_split(data_final.drop(['jam_level'], axis=1),
                                                    data_final['jam_level'],
                                                    test_size=0.3,
                                                    random_state=78)

print(f'Total Train Data = {X_train.shape[0]}')
print(f'Total Test Data = {X_test.shape[0]}')
# Out:
# Total Train Data = 7428
# Total Test Data = 3184

# %%
# Declarate Scaler Function
# scaler = RobustScaler()
# scaler = StandardScaler()
scaler = MinMaxScaler()

# Fitting Scaler with Train Data
scaler.fit(X_train)

# Scaling Train and Test Data
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)
# Create DataFrame from Scaled Array Values

X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns)

# %%
X_test_scaled.describe().T
# Out:
#                        count      mean       std       min       25%  \
# time                  3184.0  0.595777  0.185042  0.142857  0.476190
# street                3184.0  0.554556  0.269076  0.000000  0.355556
# median_length         3184.0  0.236218  0.201812  0.000000  0.075689
# median_delay_seconds  3184.0  0.366714  0.177324  0.001883  0.243691
# median_regular_speed  3184.0  0.336677  0.142822  0.026133  0.236604
# total_records         3184.0  0.202697  0.208643  0.000000  0.035088
# median_seconds        3184.0  0.375554  0.177540 -0.002994  0.255822
# median_speed          3184.0  0.305460  0.171434 -0.004764  0.177343
# geometry              3184.0  0.481295  0.293709 -0.000100  0.221232
# month                 3184.0  0.323807  0.310136  0.000000  0.000000
# day                   3184.0  0.504795  0.296492  0.000000  0.233333
#
#                            50%       75%       max
# time                  0.619048  0.714286  1.000000
# ...

# %%
# print data shape before dropping
print(X_train_scaled.shape)
print(X_test_scaled.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (7428, 11)
# (3184, 11)
# (7428,)
# (3184,)

# %% [markdown]
# ### Imbalanced

# %%
y_train.value_counts()
# Out:
# 4    4393
# 3    2840
# 2     193
# 1       2
# Name: jam_level, dtype: int64

# %%
X_train_scaled.nunique()
# Out:
# time                      20
# street                   222
# median_length           1954
# median_delay_seconds    1771
# median_regular_speed    3323
# total_records             58
# median_seconds          1936
# median_speed            2319
# geometry                7069
# month                      3
# day                       31
# dtype: int64

# %% [markdown]
# #### SMOTE

# %%
from imblearn.over_sampling import SMOTE

# Random Over Sampling
sm = SMOTE(random_state=0, k_neighbors=1)
sm.fit(X_train_scaled, y_train)
X_smote, y_smote = sm.fit_resample(X_train_scaled, y_train)
# Lets Check the Class Distribution
y_smote.value_counts()
# Out:
# 4    4393
# 3    4393
# 2    4393
# 1    4393
# Name: jam_level, dtype: int64

# %% [markdown]
# ## Modeling

# %%
# Import Metrics Evaluation

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, fbeta_score, confusion_matrix, classification_report, roc_auc_score, make_scorer

# Import Models

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier

# %%
# Create Modeling Function

def createmodel(x_train, x_test, y_train, y_test, models):
  performance = []
  for i in models:
    model = i
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    y_train_pred = model.predict(x_train)
    performance.append([np.round(precision_score(y_train, y_train_pred, average='macro', pos_label=0),5), 
                        np.round(precision_score(y_test, y_pred, average='macro',pos_label=0),5),
                       np.round(recall_score(y_train, y_train_pred,average='macro', pos_label=0),5),
                        np.round(recall_score(y_test, y_pred,average='macro', pos_label=0),5),
                        np.round(fbeta_score(y_train, y_train_pred,average='macro', pos_label=0, beta=2),5), 
                        np.round(fbeta_score(y_test, y_pred,average='macro', pos_label=0, beta=2),5)])
  performance_df = pd.DataFrame(data=performance, columns='Train\nPrecision,Test\nPrecision,Train\nRecall,Test\nRecall,Train\nF2 Score,Test\nF2 Score'.split(","),
                                index=str(models).replace('[',"").replace(']',"").replace('random_state=42',"").split(','))
  plt.figure(figsize=(14, 10))
  sns.heatmap(performance_df, annot=True, cmap="Blues", annot_kws={"fontsize":14})
  plt.tick_params(axis='both', which='major', labelsize=14, labelbottom = False, bottom=False, top = False, labeltop=True)
  plt.tight_layout()
  plt.savefig('modelling.png')
  plt.show()

# %%
# Define Classification Algorithms
models = [LogisticRegression(random_state=42), KNeighborsClassifier(), GaussianNB(), SVC(random_state=42), DecisionTreeClassifier(random_state=42),RandomForestClassifier(random_state=42), AdaBoostClassifier(random_state=42), GradientBoostingClassifier(random_state=42), LGBMClassifier(random_state=42)]

# %%
# Modeling

createmodel(X_train_scaled, X_test_scaled, y_train,y_test, models)

# %%
# Modeling

createmodel(X_smote, X_test_scaled, y_smote, y_test, models)

# %%
params = {'learning_rate': np.arange(0.05,0.2,0.05),
          'n_estimators': np.arange(50, 150, 10),
          'random_state' : [42]}

# %%
from sklearn.model_selection import GridSearchCV

# %%
f2_scorer = make_scorer(fbeta_score, pos_label=0, beta=2)
g = GridSearchCV(LGBMClassifier(), params, cv=5, scoring=f2_scorer)
g.fit(X_smote,y_smote)
# Out:
# GridSearchCV(cv=5, estimator=LGBMClassifier(),
#              param_grid={'learning_rate': array([0.05, 0.1 , 0.15, 0.2 ]),
#                          'n_estimators': array([ 50,  60,  70,  80,  90, 100, 110, 120, 130, 140]),
#                          'random_state': [42]},
#              scoring=make_scorer(fbeta_score, pos_label=0, beta=2))

# %%
GridSearchCV(cv=5, estimator=LGBMClassifier(),
             param_grid={'learning_rate': np.array([0.05, 0.1 , 0.15, 0.2 ]),
                         'n_estimators': np.array([ 50,  60,  70,  80,  90, 100, 110, 120, 130, 140]),
                         'random_state': [42]},
             scoring=make_scorer(fbeta_score, pos_label=0, beta=2))
# Out:
# GridSearchCV(cv=5, estimator=LGBMClassifier(),
#              param_grid={'learning_rate': array([0.05, 0.1 , 0.15, 0.2 ]),
#                          'n_estimators': array([ 50,  60,  70,  80,  90, 100, 110, 120, 130, 140]),
#                          'random_state': [42]},
#              scoring=make_scorer(fbeta_score, pos_label=0, beta=2))

# %%
print(g.best_params_)
# Out:
# {'learning_rate': 0.05, 'n_estimators': 50, 'random_state': 42}

# %%
print(g.best_params_)
# Out:
# {'learning_rate': 0.05, 'n_estimators': 50, 'random_state': 42}

# %%
best_params = g.best_params_
lgbm = LGBMClassifier(**best_params)
lgbm.fit(X_smote,y_smote)
# Out:
# LGBMClassifier(learning_rate=0.05, n_estimators=50, random_state=42)

# %%
LGBMClassifier(learning_rate=0.15000000000000002, n_estimators=140,
               random_state=42)
# Out:
# LGBMClassifier(learning_rate=0.15000000000000002, n_estimators=140,
#                random_state=42)

# %%
y_train_pred = lgbm.predict(X_smote)
y_test_pred = lgbm.predict(X_test_scaled)

# %%
print('TRAINING RESULT:')
print('======================================================')
print('F2 Score:', np.round(fbeta_score(y_smote, y_train_pred, average='macro', pos_label=0, beta=2),3))
print('======================================================')
print('Classification Report --------------------------------')
print(classification_report(y_smote, y_train_pred))
print('======================================================')
print('Confussion Matrix ------------------------------------')
print(confusion_matrix(y_smote, y_train_pred))

print('\n======================================================')

print('\nTESTING RESULT:')
print('======================================================')
print('F2 Score:', np.round(fbeta_score(y_test, y_test_pred, average='macro', pos_label=0, beta=2),3))
print('======================================================')
print('Classification Report --------------------------------')
print(classification_report(y_test, y_test_pred))
print('======================================================')
print('Confussion Matrix ------------------------------------')
print(confusion_matrix(y_test, y_test_pred))
# Out:
# TRAINING RESULT:
# ...
# F2 Score: 0.963
# ...
# Classification Report --------------------------------
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00      4393
#            2       0.98      1.00      0.99      4393
#            3       0.93      0.92      0.93      4393
#            4       0.94      0.93      0.94      4393
#
#     accuracy                           0.96     17572
#    macro avg       0.96      0.96      0.96     17572
# weighted avg       0.96      0.96      0.96     17572
#
# ...
# Confussion Matrix ------------------------------------
# [[4393    0    0    0]
#  [   9 4382    2    0]
#  [   0  106 4037  250]
#  [   1    2  284 4106]]
#
# ...
#
# TESTING RESULT:
# ...
# F2 Score: 0.633
# ...
# Classification Report --------------------------------
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         2
#            2       0.57      0.85      0.68        91
# ...

# %%
pip install shap
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 575.9/575.9 KB 5.6 MB/s eta 0:00:00
# ...

# %%
import shap
explainer = shap.TreeExplainer(lgbm)
shap_values = explainer.shap_values(X_test_scaled)
shap.summary_plot(shap_values[1], X_test_scaled)

# %%
shap.initjs()
shap.force_plot(explainer.expected_value[1], shap_values[1][0:1], X_test_scaled.iloc[0,:])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %%
feat_importances = pd.Series(lgbm.feature_importances_, index=X_train.columns)
feat_importances.nlargest(20).plot(kind='barh')
plt.show()
